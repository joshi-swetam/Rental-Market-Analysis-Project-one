# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
path_rental = "Resources/Average Rents_Concat.csv"
# path_Number_of_Units = pd.re("Resources/Number_of_Units_Concat.csv")
rental_df = pd.read_csv(path_rental)
rental_df
#Total rows are 8950
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 8945       B.C.    Victoria           Oak Bay     Oak Bay North
# 8946       B.C.    Victoria     North Saanich     North Saanich
# 8947       B.C.    Victoria     North Saanich     North Saanich
# 8948       B.C.    Victoria            Sidney            Sidney
# 8949       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        0.0      783.0      943.0          0.0  1166.0
# ...

# %%
#checking the datatype
rental_df.dtypes
# Out:
# Province           object
# Centre             object
# Zone               object
# Neighbourhood      object
# Dwelling Type      object
# Bachelor          float64
# 1 Bedroom         float64
# 2 Bedroom         float64
# 3 Bedroom +       float64
# Total             float64
# Year                int64
# dtype: object

# %%
#make a copy to drop na
rental_df_1= rental_df.copy()

# %%
#drop na
rental_df_1.dropna()
rental_df_1
#dropping NA's still same number of rows and we have zeroes
# Out:
#        Province      Centre                             Zone  \
# 0     Nfld.Lab.  St. John's                  St. John's East
# 1     Nfld.Lab.  St. John's                  St. John's East
# 2     Nfld.Lab.  St. John's                  St. John's West
# 3     Nfld.Lab.  St. John's                  St. John's West
# 5     Nfld.Lab.  St. John's                 Remainder of CMA
# ...         ...         ...                              ...
# 8939       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8940       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8943       B.C.    Victoria                          Oak Bay
# 8945       B.C.    Victoria                          Oak Bay
# 8949       B.C.    Victoria                           Sidney
#
#          Neighbourhood Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  \
# 0      St. John's East            Row        0.0      783.0      943.0
# 1      St. John's East    Apt & Other      664.0      829.0     1049.0
# ...

# %%
#now removing based on one column total not equal to zero
rental_df_2= rental_df[(rental_df["Total "]!=0)]
rental_df_2
#number of rows reduced to 4707
# Out:
#        Province      Centre                             Zone  \
# 0     Nfld.Lab.  St. John's                  St. John's East
# 1     Nfld.Lab.  St. John's                  St. John's East
# 2     Nfld.Lab.  St. John's                  St. John's West
# 3     Nfld.Lab.  St. John's                  St. John's West
# 5     Nfld.Lab.  St. John's                 Remainder of CMA
# ...         ...         ...                              ...
# 8939       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8940       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8943       B.C.    Victoria                          Oak Bay
# 8945       B.C.    Victoria                          Oak Bay
# 8949       B.C.    Victoria                           Sidney
#
#          Neighbourhood Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  \
# 0      St. John's East            Row        0.0      783.0      943.0
# 1      St. John's East    Apt & Other      664.0      829.0     1049.0
# ...

# %%
#rentaldf = rental_df.replace(0, np.nan, inplace=True)

# %%
#replace 0 by Nan"s
rental_df.replace(0, np.nan, inplace=True)
rental_df
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 8945       B.C.    Victoria           Oak Bay     Oak Bay North
# 8946       B.C.    Victoria     North Saanich     North Saanich
# 8947       B.C.    Victoria     North Saanich     North Saanich
# 8948       B.C.    Victoria            Sidney            Sidney
# 8949       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        NaN      783.0      943.0          NaN  1166.0
# ...

# %%
#now drop nan's
rental_df_3 = rental_df.dropna()

# %%
#now number of rows reduced to 1479 but it dropped from any column with nan
rental_df_3
# Out:
#        Province      Centre                             Zone  \
# 1     Nfld.Lab.  St. John's                  St. John's East
# 3     Nfld.Lab.  St. John's                  St. John's West
# 7          N.S.     Halifax                  Peninsula South
# 9          N.S.     Halifax                  Peninsula South
# 11         N.S.     Halifax                  Peninsula South
# ...         ...         ...                              ...
# 8925       B.C.    Victoria          Saanich/Central Saanich
# 8927       B.C.    Victoria          Saanich/Central Saanich
# 8933       B.C.    Victoria                        Esquimalt
# 8935       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8937       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
#
#             Neighbourhood Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  \
# 1         St. John's East    Apt & Other      664.0      829.0     1049.0
# 3         St. John's West    Apt & Other      762.0      773.0      881.0
# ...

# %%
#extract 2022
rental_df_2022 = rental_df_3.loc[(rental_df_3["Year"]==2022)]

# %%
#mean will be higher because number of rows have been reduced
rental_df_2022.mean()
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_4192\1487897114.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rental_df_2022.mean()
# Bachelor        951.943463
# 1 Bedroom      1158.929329
# 2 Bedroom      1406.918728
# 3 Bedroom +    1696.558304
# Total          1280.392226
# Year           2022.000000
# dtype: float64

# %%
# Out:
#        Province      Centre                             Zone  \
# 0     Nfld.Lab.  St. John's                  St. John's East
# 1     Nfld.Lab.  St. John's                  St. John's East
# 2     Nfld.Lab.  St. John's                  St. John's West
# 3     Nfld.Lab.  St. John's                  St. John's West
# 5     Nfld.Lab.  St. John's                 Remainder of CMA
# ...         ...         ...                              ...
# 8939       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8940       B.C.    Victoria  Langford/Vw Royal/Colwood/Sooke
# 8943       B.C.    Victoria                          Oak Bay
# 8945       B.C.    Victoria                          Oak Bay
# 8949       B.C.    Victoria                           Sidney
#
#          Neighbourhood Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  \
# 0      St. John's East            Row        0.0      783.0      943.0
# 1      St. John's East    Apt & Other      664.0      829.0     1049.0
# ...
