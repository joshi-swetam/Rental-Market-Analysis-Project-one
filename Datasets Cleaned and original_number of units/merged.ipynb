# %%
import pandas as pd
import numpy as np

# %%
filepath_2018 = "Number_of_units_clean_2018.csv"
filepath_2019 = "Number_of_units_clean_2019.csv"
filepath_2020 = "Number_of_units_clean_2020.csv"
filepath_2021 = "Number_of_units_clean_2021.csv"
filepath_2022 = "Number_of_units_clean_2022.csv"

# %%
df_2018 = pd.read_csv(filepath_2018)
df_2019 = pd.read_csv(filepath_2019)
df_2020 = pd.read_csv(filepath_2020)
df_2021 = pd.read_csv(filepath_2021)
df_2022 = pd.read_csv(filepath_2022)

# %%
df_2018_wy = df_2018.loc[:, df_2018.columns != "Year"]
df_2019_wy = df_2019.loc[:, df_2019.columns != "Year"]
df_2020_wy = df_2020.loc[:, df_2020.columns != "Year"]
df_2021_wy = df_2021.loc[:, df_2021.columns != "Year"]
df_2022_wy = df_2022.loc[:, df_2022.columns != "Year"]

# %%
df_18_19 = pd.merge(df_2018_wy,df_2019_wy, how = "outer", on =[ "Province","Centre","Zone","Neighbourhood","Dwelling Type "], suffixes = (" 18" ," 19"))

# %%
df_18_19
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor  18  1 Bedroom 18  2 Bedroom 18  3 Bedroom + 18  \
# 0               Row           1.0          22.0          16.0            16.0
# ...

# %%
df_20 = pd.merge(df_18_19,df_2020_wy, how = "outer", on =[ "Province","Centre","Zone","Neighbourhood","Dwelling Type "])

# %%
df_20
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor  18  1 Bedroom 18  2 Bedroom 18  3 Bedroom + 18  \
# 0               Row           1.0          22.0          16.0            16.0
# ...

# %%
df_21 = pd.merge(df_20,df_2021_wy, how = "outer", on =[ "Province","Centre","Zone","Neighbourhood","Dwelling Type "], suffixes = (" 20"," 21"))

# %%
df_21
# Out:
#        Province      Centre                     Zone            Neighbourhood  \
# 0     Nfld.Lab.  St. John's          St. John's East          St. John's East
# 1     Nfld.Lab.  St. John's          St. John's East          St. John's East
# 2     Nfld.Lab.  St. John's          St. John's West          St. John's West
# 3     Nfld.Lab.  St. John's          St. John's West          St. John's West
# 4     Nfld.Lab.  St. John's         Remainder of CMA         Remainder of CMA
# ...         ...         ...                      ...                      ...
# 1787       B.C.    Victoria            North Saanich            North Saanich
# 1788       B.C.    Victoria                   Sidney                   Sidney
# 1789       B.C.    Victoria                   Sidney                   Sidney
# 1790        Que    Montréal  Saint-Lin-Laurentides V  Saint-Lin–Laurentides V
# 1791        Que    Montréal  Saint-Lin-Laurentides V  Saint-Lin–Laurentides V
#
# ...

# %%
df_22 = pd.merge(df_21,df_2022_wy, how = "outer", on =[ "Province","Centre","Zone","Neighbourhood","Dwelling Type "])

# %%
df_22
# Out:
#        Province      Centre                     Zone            Neighbourhood  \
# 0     Nfld.Lab.  St. John's          St. John's East          St. John's East
# 1     Nfld.Lab.  St. John's          St. John's East          St. John's East
# 2     Nfld.Lab.  St. John's          St. John's West          St. John's West
# 3     Nfld.Lab.  St. John's          St. John's West          St. John's West
# 4     Nfld.Lab.  St. John's         Remainder of CMA         Remainder of CMA
# ...         ...         ...                      ...                      ...
# 1787       B.C.    Victoria            North Saanich            North Saanich
# 1788       B.C.    Victoria                   Sidney                   Sidney
# 1789       B.C.    Victoria                   Sidney                   Sidney
# 1790        Que    Montréal  Saint-Lin-Laurentides V  Saint-Lin–Laurentides V
# 1791        Que    Montréal  Saint-Lin-Laurentides V  Saint-Lin–Laurentides V
#
# ...

# %%
df_22.columns
# Out:
# Index(['Province', 'Centre', 'Zone', 'Neighbourhood', 'Dwelling Type ',
#        'Bachelor  18', '1 Bedroom 18', '2 Bedroom 18', '3 Bedroom + 18',
#        'Total  18', 'Bachelor  19', '1 Bedroom 19', '2 Bedroom 19',
#        '3 Bedroom + 19', 'Total  19', 'Bachelor  20', '1 Bedroom 20',
#        '2 Bedroom 20', '3 Bedroom + 20', 'Total  20', 'Bachelor  21',
#        '1 Bedroom 21', '2 Bedroom 21', '3 Bedroom + 21', 'Total  21',
#        'Bachelor ', '1 Bedroom', '2 Bedroom', '3 Bedroom +', 'Total '],
#       dtype='object')

# %%
df_combined = df_22.rename(columns = {'Bachelor ':'Bachelor  22' , 
                                      '1 Bedroom': '1 Bedroom 22' , 
                                      '2 Bedroom': '2 Bedroom 22',
                                      '3 Bedroom +' : '3 Bedroom + 22' , 'Total ': 'Total  22'})

# %%
df_combined = df_combined.fillna(0)

# %%
df_combined.to_csv("Number_of_units_merged_clean.csv",index=False)
