# %%
#import dependencies
import pandas as pd
import numpy as np

# %%
#define path 
filepath_2018 = "VR_clean_2018.csv"
filepath_2019 = "VR_clean_2019.csv"
filepath_2020 = "VR_clean_2020.csv"
filepath_2021 = "VR_clean_2021.csv"
filepath_2022 = "VR_clean_2022.csv"

# %%
#read files
df_2018 = pd.read_csv(filepath_2018)
df_2019 = pd.read_csv(filepath_2019)
df_2020 = pd.read_csv(filepath_2020)
df_2021 = pd.read_csv(filepath_2021)
df_2022 = pd.read_csv(filepath_2022)

# %%
df_2019
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        NaN        NaN        NaN          NaN     NaN
# ...

# %%
df_2020
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        NaN        NaN        NaN          NaN     NaN
# ...

# %%
df_2021
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        NaN        NaN        NaN          NaN     NaN
# ...

# %%
df_2022
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        NaN        NaN        NaN          NaN     NaN
# ...

# %%
combined_df = pd.merge(df_2019,df_2020, on= ["Province", "Centre", "Zone", "Neighbourhood"], how = "left")

# %%
combined_df
# Out:
#        Province      Centre             Zone    Neighbourhood  \
# 0     Nfld.Lab.  St. John's  St. John's East  St. John's East
# 1     Nfld.Lab.  St. John's  St. John's East  St. John's East
# 2     Nfld.Lab.  St. John's  St. John's East  St. John's East
# 3     Nfld.Lab.  St. John's  St. John's East  St. John's East
# 4     Nfld.Lab.  St. John's  St. John's West  St. John's West
# ...         ...         ...              ...              ...
# 3575       B.C.    Victoria    North Saanich    North Saanich
# 3576       B.C.    Victoria           Sidney           Sidney
# 3577       B.C.    Victoria           Sidney           Sidney
# 3578       B.C.    Victoria           Sidney           Sidney
# 3579       B.C.    Victoria           Sidney           Sidney
#
#      Dwelling Type _x  Bachelor _x  1 Bedroom_x  2 Bedroom_x  3 Bedroom +_x  \
# 0                 Row          NaN          NaN          NaN            NaN
# ...

# %%
#concatenate on rows
VR_combined_df = pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022],axis = 0)

# %%
VR_combined_df
# Out:
#        Province      Centre              Zone     Neighbourhood  \
# 0     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 1     Nfld.Lab.  St. John's   St. John's East   St. John's East
# 2     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 3     Nfld.Lab.  St. John's   St. John's West   St. John's West
# 4     Nfld.Lab.  St. John's  Remainder of CMA  Remainder of CMA
# ...         ...         ...               ...               ...
# 1785       B.C.    Victoria           Oak Bay     Oak Bay North
# 1786       B.C.    Victoria     North Saanich     North Saanich
# 1787       B.C.    Victoria     North Saanich     North Saanich
# 1788       B.C.    Victoria            Sidney            Sidney
# 1789       B.C.    Victoria            Sidney            Sidney
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# 0               Row        NaN        NaN        NaN          NaN     NaN
# ...

# %%
#save 
VR_combined_df.to_csv("VR_combined_clean_.csv",index=False)
