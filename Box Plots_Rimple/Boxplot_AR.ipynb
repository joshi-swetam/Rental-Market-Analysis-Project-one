# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# define paths for the datasets to be used
path_rental = "Resources/Average Rents_Concat.csv"
path_units = "Resources/Number_of_Units_Concat.csv"
path_vacancy = "Resources/Vacancy Rate Concat.csv"

# %%
#read into files
rental_df = pd.read_csv(path_rental)
units_df = pd.read_csv(path_units)
vacancy_df = pd.read_csv(path_vacancy)
rental_df.columns
# Out:
# Index(['Province', 'Centre', 'Zone', 'Neighbourhood', 'Dwelling Type ',
#        'Bachelor ', '1 Bedroom', '2 Bedroom', '3 Bedroom +', 'Total ', 'Year'],
#       dtype='object')

# %%
# units_df = units_df.loc[(units_df["Year"] == 2022 )& (units_df["Province"] == "Que")]
# units_df["Total "].sum()

# %%
print(rental_df["Province"].unique())
# Out:
# ['Nfld.Lab.' 'N.S.' 'N.B.' 'Que' 'Ont.' 'Man.' 'Sask.' 'Alta' 'B.C.']

# %%
def box_plot(filepath,Province,Year,column):
    get_df = pd.read_csv(filepath)
    df = rental_df.loc[(rental_df["Year"] == Year )& (rental_df["Province"] == Province)]
    df_Province = df[(df[column]!=0)]
    return df_Province

# %%
df_Ontario = box_plot(path_rental,"Ont.",2022,"Total ")
df_Ontario
# Out:
#      Province   Centre              Zone      Neighbourhood Dwelling Type   \
# 7669     Ont.   Barrie            Barrie           Downtown    Apt & Other
# 7671     Ont.   Barrie            Barrie           West End    Apt & Other
# 7673     Ont.   Barrie            Barrie       North Barrie    Apt & Other
# 7675     Ont.   Barrie            Barrie           East End    Apt & Other
# 7676     Ont.   Barrie            Barrie       South Barrie            Row
# ...       ...      ...               ...                ...            ...
# 8353     Ont.  Windsor              West         University    Apt & Other
# 8355     Ont.  Windsor              West           Sandwich    Apt & Other
# 8357     Ont.  Windsor              West  Southwest Windsor    Apt & Other
# 8359     Ont.  Windsor       Amherstburg        Amherstburg    Apt & Other
# 8361     Ont.  Windsor  Remainder of CMA   Remainder of CMA    Apt & Other
#
#       Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   Year
# ...

# %%
#Provinces of interest
Province_1 = "Ont."
Province_2 = "Que"
Province_3 = "B.C."
Province_4 = "N.S."
Province_5 = "Nfld.Lab."
Province_6 = "Man." 
Province_7 = "Alta"
Province_8 = 'Sask.'
Province_9 = "N.B."
Year = 2022
column = "Bachelor "

# %%
Province = [Province_1 ,Province_2 , Province_3,Province_4 ,Province_5 , Province_6,Province_7 ,Province_8 , Province_9]

# %%
df
# Out:
#      Province      Centre              Zone  \
# 7218     N.B.     Moncton   Central Moncton
# 7219     N.B.     Moncton   Central Moncton
# 7220     N.B.     Moncton   Central Moncton
# 7221     N.B.     Moncton   Central Moncton
# 7222     N.B.     Moncton      West Moncton
# 7223     N.B.     Moncton      West Moncton
# 7224     N.B.     Moncton      East Moncton
# 7225     N.B.     Moncton      East Moncton
# 7226     N.B.     Moncton      East Moncton
# 7227     N.B.     Moncton      East Moncton
# 7228     N.B.     Moncton      East Moncton
# 7229     N.B.     Moncton      East Moncton
# 7230     N.B.     Moncton      East Moncton
# 7231     N.B.     Moncton      East Moncton
# 7232     N.B.     Moncton     North Moncton
# 7233     N.B.     Moncton     North Moncton
# 7234     N.B.     Moncton     North Moncton
# 7235     N.B.     Moncton     North Moncton
# 7236     N.B.     Moncton         Riverview
# 7237     N.B.     Moncton         Riverview
# ...

# %%
Province_1_df = rental_df.loc[(rental_df["Year"] == Year )& (rental_df["Province"] == Province_1)]
Province_2_df = rental_df.loc[(rental_df["Year"] ==  Year )& (rental_df["Province"] == Province_2)]
Province_3_df = rental_df.loc[(rental_df["Year"] == Year ) & (rental_df["Province"] == Province_3)]
Province_4_df = rental_df.loc[(rental_df["Year"] == Year )& (rental_df["Province"] == Province_4)]
Province_5_df = rental_df.loc[(rental_df["Year"] ==  Year )& (rental_df["Province"] == Province_5)]
Province_6_df = rental_df.loc[(rental_df["Year"] == Year ) & (rental_df["Province"] == Province_6)]
Province_7_df = rental_df.loc[(rental_df["Year"] == Year )& (rental_df["Province"] == Province_7)]
Province_8_df = rental_df.loc[(rental_df["Year"] ==  Year )& (rental_df["Province"] == Province_8)]
Province_9_df = rental_df.loc[(rental_df["Year"] == Year ) & (rental_df["Province"] == Province_9)]

# %%
df1= Province_1_df[(Province_1_df[column]!=0)]
df2= Province_2_df[(Province_2_df[column]!=0)]
df3= Province_3_df[(Province_3_df[column]!=0)]
df4= Province_4_df[(Province_4_df[column]!=0)]
df5= Province_5_df[(Province_5_df[column]!=0)]
df6= Province_6_df[(Province_6_df[column]!=0)]
df7= Province_7_df[(Province_7_df[column]!=0)]
df8= Province_8_df[(Province_8_df[column]!=0)]
df9= Province_9_df[(Province_9_df[column]!=0)]

# %%
df1
# Out:
#      Province      Centre                Zone           Neighbourhood  \
# 7669     Ont.      Barrie              Barrie                Downtown
# 7683     Ont.  Belleville  City of Belleville  Belleville (Southwest)
# 7699     Ont.   Brantford           Brantford          Brantford East
# 7703     Ont.   Brantford           Brantford         Brantford North
# 7709     Ont.      Guelph                West                    West
# ...       ...         ...                 ...                     ...
# 8341     Ont.     Windsor          East Inner        East Walkerville
# 8343     Ont.     Windsor          East Outer               Riverside
# 8347     Ont.     Windsor          East Outer           Fontainebleau
# 8353     Ont.     Windsor                West              University
# 8355     Ont.     Windsor                West                Sandwich
#
#      Dwelling Type   Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   \
# ...

# %%
combined_data = [df1[column],df2[column],df3[column],df4[column],df5[column],df6[column],df7[column],df8[column],df9[column]]
out_patch = dict(markerfacecolor = "red", marker = "o",alpha = 0.6)
box_plot = plt.boxplot(x = combined_data,labels = Province, flierprops = out_patch,patch_artist = True)
color = ["Cyan"]
colors = color*9
plt.xlabel("Province",fontsize = 12)
plt.ylabel("Average Rents (Total)",fontsize = 12)
plt.title(f"Average Rents Provinces {Year} {column}",fontsize = 12)

for patch,color in zip(box_plot["boxes"],colors):
    patch.set_facecolor(color)
plt.savefig(f"Average Rents Provinces {Year} {column}.png")          
plt.show()

# %%
columns = "Total "
df_Ontario = rental_df[(rental_df["Province"]==Province_1) & (rental_df[col]!=0)]
df_Ontario
# Out:
#      Province   Centre              Zone      Neighbourhood Dwelling Type   \
# 509      Ont.   Barrie            Barrie           Downtown    Apt & Other
# 511      Ont.   Barrie            Barrie           West End    Apt & Other
# 513      Ont.   Barrie            Barrie       North Barrie    Apt & Other
# 515      Ont.   Barrie            Barrie           East End    Apt & Other
# 516      Ont.   Barrie            Barrie       South Barrie            Row
# ...       ...      ...               ...                ...            ...
# 8353     Ont.  Windsor              West         University    Apt & Other
# 8355     Ont.  Windsor              West           Sandwich    Apt & Other
# 8357     Ont.  Windsor              West  Southwest Windsor    Apt & Other
# 8359     Ont.  Windsor       Amherstburg        Amherstburg    Apt & Other
# 8361     Ont.  Windsor  Remainder of CMA   Remainder of CMA    Apt & Other
#
#       Bachelor   1 Bedroom  2 Bedroom  3 Bedroom +  Total   Year
# ...

# %%
df_Ontario.columns
# Out:
# Index(['Province', 'Centre', 'Zone', 'Neighbourhood', 'Dwelling Type ',
#        'Bachelor ', '1 Bedroom', '2 Bedroom', '3 Bedroom +', 'Total ', 'Year'],
#       dtype='object')

# %%
df_Ontario["Centre"].unique()
# Out:
# array(['Barrie', 'Belleville', 'Brantford', 'Guelph', 'Hamilton',
#        'Kingston', 'Kitchener - Cambridge - Waterl', 'London',
#        'St. Catharines - Niagara', 'Oshawa', 'Ottawa', 'Peterborough',
#        'Greater Sudbury / Grand Sudbur', 'Thunder Bay', 'Toronto',
#        'Windsor'], dtype=object)

# %%
df_Ontario = df_Ontario[['Centre','Year',col]]

Centre_for_trend =['Barrie', 'Belleville', 'Brantford', 'Guelph', 'Hamilton',
       'Kingston', 'Kitchener - Cambridge - Waterl', 'London',
       'St. Catharines - Niagara', 'Oshawa', 'Ottawa', 'Peterborough',
       'Greater Sudbury / Grand Sudbur', 'Thunder Bay', 'Toronto',
       'Windsor']

df_Ontario = df_Ontario[(df_Ontario['Centre'].isin(Centre_for_trend))]

df_Ontario = pd.pivot_table(df_Ontario, index='Year', columns='Centre', aggfunc='mean', fill_value=0).reset_index()

df_Ontario.columns = ["Year", 'Barrie', 'Belleville', 'Brantford', 'Guelph', 'Hamilton',
       'Kingston', 'Kitchener - Cambridge - Waterl', 'London',
       'St. Catharines - Niagara', 'Oshawa', 'Ottawa', 'Peterborough',
       'Greater Sudbury / Grand Sudbur', 'Thunder Bay', 'Toronto',
       'Windsor']

df_Ontario.head()
# Out:
#    Year       Barrie  Belleville    Brantford       Guelph     Hamilton  \
# 0  2018  1298.666667      961.00   987.428571  1008.133333  1188.166667
# 1  2019  1330.166667      988.20  1019.428571  1035.571429  1267.400000
# 2  2020  1394.666667     1075.75  1116.714286  1084.625000  1398.600000
# 3  2021  1469.666667     1110.40  1177.142857  1240.500000  1389.800000
# 4  2022  1543.666667     1211.20  1252.250000  1093.500000  1477.200000
#
#       Kingston  Kitchener - Cambridge - Waterl       London  \
# 0  1148.785714                     1164.846154  1090.961538
# 1  1157.142857                     1238.866667  1120.833333
# 2  1239.481481                     1269.933333  1173.538462
# 3  1300.200000                     1354.500000  1260.954545
# 4  1382.428571                     1366.062500  1305.714286
#
#    St. Catharines - Niagara       Oshawa       Ottawa  Peterborough  \
# 0               1000.103448  1305.571429  1251.375000   1032.666667
# ...
